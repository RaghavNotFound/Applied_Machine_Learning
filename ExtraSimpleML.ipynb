# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("House_Rent_Dataset.csv")

# %%
df.head()
# Out:
#     Posted On  BHK     Rent  Size         Floor    Area Type  \
# 0  2022-06-08    3   500000  2500    4 out of 4  Carpet Area
# 1  2022-06-01    4  1200000  5000   4 out of 15  Carpet Area
# 2  2022-05-18    4  1000000  3064  18 out of 45  Carpet Area
# 3  2022-06-23    4   850000  3200    2 out of 4  Carpet Area
# 4  2022-06-27    4   700000  3200  24 out of 24  Carpet Area
#
#              Area Locality       City Furnishing Status  Tenant Preferred  \
# 0             Marathahalli  Bangalore    Semi-Furnished         Bachelors
# 1                     Juhu     Mumbai    Semi-Furnished  Bachelors/Family
# 2    Raheja Artesia, Worli     Mumbai    Semi-Furnished            Family
# 3             Breach Candy     Mumbai         Furnished  Bachelors/Family
# 4  Lady Ratan Tower, Worli     Mumbai         Furnished  Bachelors/Family
#
#    Bathroom Point of Contact
# 0         3    Contact Agent
# 1         4    Contact Agent
# 2         4    Contact Agent
# 3         4    Contact Agent
# 4         4    Contact Agent

# %%
plt.scatter(df["Size"],df["Rent"])
plt.xlabel("Size")
plt.ylabel("Rent")
plt.show()

# %%
X = df.loc[:, ['Size']]
X
# Out:
#       Size
# 0     2500
# 1     5000
# 2     3064
# 3     3200
# 4     3200
# ...    ...
# 4741   700
# 4742    60
# 4743   500
# 4744   200
# 4745  2100
#
# [4746 rows x 1 columns]

# %%
y=df.loc[:,['Rent']]
y
# Out:
#          Rent
# 0      500000
# 1     1200000
# 2     1000000
# 3      850000
# 4      700000
# ...       ...
# 4741     2200
# 4742     2000
# 4743     1800
# 4744     1500
# 4745     1200
#
# [4746 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test =train_test_split(X,y,test_size=0.2,random_state=2)

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()

# %%
x_train
# Out:
#       Size
# 2880  1000
# 3067   900
# 4317   800
# 4418   570
# 3656   700
# ...    ...
# 3335   500
# 1099  1600
# 2514   700
# 3606   900
# 2575  1000
#
# [3796 rows x 1 columns]

# %%
y_train
# Out:
#        Rent
# 2880  13000
# 3067  12000
# 4317   7000
# 4418   6166
# 3656  10000
# ...     ...
# 3335  11000
# 1099  35000
# 2514  15000
# 3606  10000
# 2575  15000
#
# [3796 rows x 1 columns]

# %%
lr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
m=lr.coef_
m
# Out:
# array([[47.11988467]])

# %%
b=lr.intercept_
b
# Out:
# array([-11518.39837612])

# %%
y_pred=lr.predict(x_test)
y_pred[:10]
# Out:
# array([[ 7329.55549348],
#        [ 2617.56702608],
#        [40313.47476527],
#        [61517.42286857],
#        [ 3559.96471956],
#        [23821.51512938],
#        [12041.54396088],
#        [30983.73759982],
#        [34423.48918102],
#        [ 4973.56125978]])

# %%
plt.scatter(df["Size"],df["Rent"])
plt.plot(x_train,lr.predict(x_train),color="red")
plt.xlabel("Size")
plt.ylabel("Rent")
plt.show()
